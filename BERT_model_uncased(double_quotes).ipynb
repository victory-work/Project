# %%
# !pip install transformers
# !pip install gdown
# !pip install textattack fastapi kaleido python-multipart uvicorn

# %%
import textattack

# %%
# !rm -rf Project
# !git clone https://github.com/victory-work/Project.git
# Out:
# Cloning into 'Project'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 235 (delta 60), reused 207 (delta 32), pack-reused 0
# Receiving objects: 100% (235/235), 352.16 KiB | 6.40 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
import torch
torch.cuda.empty_cache()

# %%
# train the model
# !python Project/program/1_train_model.py
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2023-11-13 12:51:09.493060: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# load the trained model(uncased model) from the google cloud
import gdown
url = "https://drive.google.com/uc?id=1BGXclV06ADpHSQlMLWF1BfhdyVwQ-HRL"
output = "dataset.zip"
gdown.download(url, output)

import zipfile
with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BGXclV06ADpHSQlMLWF1BfhdyVwQ-HRL
# To: /content/dataset.zip
# 100%|██████████| 406M/406M [00:03<00:00, 127MB/s]

# %%
# get the data that predict correctly
# !python Project/program/2_check_malicious.py
# Out:
# 2023-11-13 14:39:04.266393: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-13 14:39:04.266457: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-13 14:39:04.266507: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-13 14:39:05.878117: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# cuda
# ...

# %%
# carry out textattack
# !python Project/program/3_textattack1.py
# Out:
# 2023-11-13 15:02:32.504674: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-13 15:02:32.504741: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-13 15:02:32.504791: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-13 15:02:34.567122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Unknown if model of class <class 'func_def.BERTClassifier'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# ...
